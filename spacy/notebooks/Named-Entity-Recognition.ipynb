# %% [markdown]
# # Named Entity Recognition

# %% [markdown]
# [Download relevant files](https://melaniewalsh.org/spacy.zip)

# %% [markdown]
# In this lesson, we're going to learn about a text analysis method called **Named Entity Recognition** (NER). This method will help us computationally identify people, places, and things (of various kinds) in a text or collection of texts.

# %% [markdown]
# <img src="../images/Ada-Lovelace-NER.png" width="100%">

# %% [markdown]
# # Why is NER Useful?

# %% [markdown]
# Named Entity Recognition is useful for extracting key information from texts. You might use NER to identify the most frequently appearing characters in a novel or build a network of characters (something we'll do in a later lesson!). Or you might use NER to identify the geographic locations mentioned in texts, a first step toward mapping the locations (something we'll also do in a later lesson!).

# %% [markdown]
# # Natural Language Processing (NLP)

# %% [markdown]
# Named Entity Recognition is a fundamental task in the field of *natural language processing* (NLP). What is NLP, exactly? NLP is an interdisciplinary field that blends linguistics, statistics, and computer science. The heart of NLP is to understand human language with statistics and computers. Applications of NLP are all around us. Have you ever heard of a little thing called *spellcheck*? How about autocomplete, Google translate, chat bots, and Siri? These are all examples of NLP in action!
#
# Thanks to recent advances in machine learning and to increasing amounts of available text data on the web, NLP has grown by leaps and bounds in the last decade. NLP models that generate texts are now getting eerily good. (If you don't believe me, check out [this app that will autocomplete your sentences](https://transformer.huggingface.co/doc/gpt2-large/qCNMTfzephfZMBkryTNvSRKQ/edit) with GPT-2, a state-of-the-art text generation model. When I ran it, the model generated a mini-lecture from a "university professor" that sounds spookily close to home...)

# %% [markdown]
# <img src="../images/GPT-2.png">

# %% [markdown]
# Open-source NLP tools are getting very good, too. We're going to use one of these open-source tools, the Python library `spaCy`, for our Named Entity Recognition tasks in this lesson.

# %% [markdown]
# # How spaCy Works

# %% [markdown]
# <img src="../images/Ada-Lovelace-NER.png">

# %% [markdown]
# The screenshot above shows spaCy correctly identifying named entities in Ada Lovelace's *New York Times* obituary (something that we'll test out for ourselves below). How does spaCy know that "Ada Lovelace" is a person and that "1843" is a date?

# %% [markdown]
# Well, spaCy doesn't *know*, not for sure anyway. Instead, spaCy is making a very educated guess. This "guess" is based on what spaCy has learned about the English language after seeing lots of other examples.

# %% [markdown]
# That's a colloquial way of saying: spaCy relies on machine learning models that were trained on a large amount of carefully-labeled texts. (These texts were, in fact, often labeled and corrected by hand). This is similar to our <a href="https://melaniewalsh.github.io/Intro-Cultural-Analytics/Text-Analysis/Topic-Modeling-Overview.html#1)-LDA-is-an-Unsupervised-Algorithm">topic modeling work</a> from the previous lesson, except our topic model wasn't using labeled data.
#
# The English-language spaCy model that we're going to use in this lesson was trained on an annotated corpus called ["OntoNotes"](https://catalog.ldc.upenn.edu/docs/LDC2013T19/OntoNotes-Release-5.0.pdf): 2 million+ words drawn from "news, broadcast, talk shows, weblogs, usenet newsgroups, and conversational telephone speech," which were meticulously tagged by a group of researchers and professionals for people's names and places, for nouns and verbs, for subjects and objects, and much more. (Like a lot of other major machine learning projects, OntoNotes was also sponsored by the Defense Advaced Research Projects Agency (DARPA), the branch of the Defense Department that develops technology for the U.S. military.)
#
# When spaCy identifies people and places in Ada Lovelace's obituary, in other words, its NLP model is actually making a series of *predictions* about the text based on what it has learned about how people and places function in English-language sentences.

# %% [markdown]
# # NER with spaCy

# %% [markdown]
# # Install spaCy

# %% [markdown]
# To use spaCy, we first need to install the library.

# %%
# !pip install -U spacy

# %% [markdown]
# # Import Libraries

# %% [markdown]
# Then we're going to import `spacy` and `displacy`, a special spaCy module for visualization.

# %%
import spacy
from spacy import displacy

# %% [markdown]
# We're also going to import the `Counter` module for counting people, places, and things, and the `pandas` library for organizing and displaying data (we're also changing the pandas default max row and column width display setting).

# %%
from collections import Counter

# %%
import pandas as pd
pd.set_option("max_rows", 400)
pd.set_option("max_colwidth", 400)

# %% [markdown]
# # Download Language Model

# %% [markdown]
# Next we need to download the English-language model (`en_core_web_sm`), which will be processing and making predictions about our texts. This is the model that was trained on the annotated "OntoNotes" corpus. You can download the `en_core_web_sm` model by running the cell below:

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: en_core_web_sm==2.1.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.1.0/en_core_web_sm-2.1.0.tar.gz#egg=en_core_web_sm==2.1.0 in /Users/melaniewalsh/anaconda3/lib/python3.7/site-packages (2.1.0)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %% [markdown]
# *Note: spaCy offers [models for other languages](https://spacy.io/usage/models#languages) including German, French, Spanish, Portuguese, Italian, Dutch, Greek, Norwegian, and Lithuanian. Languages such as Russian, Ukrainian, Thai, Chinese, Japanese, Korean and Vietnamese don't currently have their own NLP models. However, spaCy offers language and tokenization support for many of these language with external dependencies — such as [PyviKonlpy](https://github.com/konlpy/konlpy) for Korean or [Jieba](https://github.com/fxsjy/jieba) for Chinese.*

# %% [markdown]
# # Load Language Model

# %% [markdown]
# Once the model is downloaded, we need to load it with `spacy.load()` and assign it to the variable `nlp`.

# %%
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# # Create a Processed spaCy Document

# %% [markdown]
# `document = nlp(open(filepath, , encoding='utf-8').read())`

# %% [markdown]
# Whenever we use spaCy, our first step will be to create a processed spaCy `document` with the loaded NLP model `nlp()`. Most of the heavy NLP lifting is done in this line of code. After processing, the `document` object will contain tons of juicy language data — named entities, sentence boundaries, parts of speech — and the rest of our work will be devoted to accessing this information.
#
# In the cell below, we `open()` and `.read()` Ada Lovelace's obituary. Then we run`nlp()` on the text and create our `document`.

# %%
filepath = "../texts/history/NYT-Obituaries/1852-Ada-Lovelace.txt"

document = nlp(open(filepath, encoding='utf-8').read())

# %% [markdown]
# # spaCy Named Entities

# %% [markdown]
# |Type Label|Description|
# |:---:|:---:|
# |PERSON|People, including fictional.|
# |NORP|Nationalities or religious or political groups.|
# |FAC|Buildings, airports, highways, bridges, etc.|
# |ORG|Companies, agencies, institutions, etc.|
# |GPE|Countries, cities, states.|
# |LOC|Non-GPE locations, mountain ranges, bodies of water.|
# |PRODUCT|Objects, vehicles, foods, etc. (Not services.)|
# |EVENT|Named hurricanes, battles, wars, sports events, etc.|
# |WORK_OF_ART|Titles of books, songs, etc.|
# |LAW|Named documents made into laws.|
# |LANGUAGE|Any named language.|
# |DATE|Absolute or relative dates or periods.|
# |TIME|Times smaller than a day.|
# |PERCENT|Percentage, including ”%“.|
# |MONEY|Monetary values, including unit.|
# |QUANTITY|Measurements, as of weight or distance.|
# |ORDINAL|“first”, “second”, etc.|
# |CARDINAL|Numerals that do not fall under another type.|

# %% [markdown]
# Above is a Named Entities chart taken from [spaCy's website](https://spacy.io/api/annotation#named-entities), which shows the different named entities that spaCy can identify as well as their corresponding type labels. To quickly see spaCy's NER in action, we can use the [spaCy module `displacy`](https://spacy.io/usage/visualizers#ent) with the `style=` parameter set to "ent"  (short for entities):

# %%
displacy.render(document, style="ent")
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">A gifted mathematician who is nowrecognized as the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  computer programmer.By CLAIRE CAIN MILLER</br></br> A century before the dawn of the computer age,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Ada Lovelace
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  imagined the modern-day, general-purpose computer. It could be programmed to follow instructions, she wrote in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     1843
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . It could not just calculate but also create, as it “weaves algebraic patterns just as the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Jacquard
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  loom weaves flowers and leaves.” The computer she was writing about, the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     British
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  inventor
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Charles Babbage’s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  Analytical Engine, was never built. But her writings about computing have earned
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Lovelace —
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  who died of uterine cancer in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     1852
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  at
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     36
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  — recognition as the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  computer programmer. </br></br> The program she wrote for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the Analytical Engine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  was to calculate the seventh Bernoulli number. (Bernoulli numbers, named after the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Swiss
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  mathematician
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Jacob Bernoulli
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , are used in many different areas of mathematics.) But her deeper influence was to see the potential of computing. The machines could go beyond calculating numbers, she said, to understand symbols and be used to create music or art.</br></br> “This insight would become the core concept of the digital age,”
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Walter Isaacson
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  wrote in his book “
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     The Innovators
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# .” “Any piece of content, data or information — music, text, pictures, numbers, symbols, sounds, video — could be expressed in digital form and manipulated by machines.” She also explored the ramifications of what a computer could do, writing about the responsibility placed on the person programming the machine, and raising and then dismissing the notion that computers could someday think and create on their own — what we now call artificial intelligence.</br></br> “The Analytical Engine has no pretensions whatever to originate any thing,” she wrote. “It can do whatever we know how to order it to perform.”</br></br> Lovelace, a
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     British
#     <span style="font-size: 0.8em; font-weight:

# %% [markdown]
# From a quick glance at the text above, we can see that spaCy is doing quite well with NER. But it's definitely not perfect.
#
# Though spaCy correctly identifies "Ada Lovelace" as a `PERSON` in the first sentence, just a few sentences later it labels her as a `WORK_OF_ART`. Though spaCy correctly identifies "London" as a place `GPE` a few paragraphs down, it incorrectly identifies "Jacquard" as a place `GPE`, too (when really "Jacquard" is a type of loom, named after [Marie Jacquard](https://en.wikipedia.org/wiki/Jacquard_machine)).
#
# This inconsistency is very important to note and keep in mind. If we wanted to use spaCy's NER for a project, it would almost certainly require manual correction and cleaning. And even then it wouldn't be perfect. That's why understanding the limitations of this tool is so crucial. While spaCy's NER can be very good for identifying entities in broad strokes, it can't be relied upon for anything exact and fine-grained — not out of the box anyway.

# %% [markdown]
# # Get Named Entities

# %% [markdown]
# All the named entities in our `document` can be found in the `document.ents` property. If we check out `document.ents`, we can see all the entities from Ada Lovelace's obituary.

# %%
document.ents
# Out:
# (first,
#  Ada Lovelace,
#  1843,
#  Jacquard,
#  British,
#  Charles Babbage’s,
#  Lovelace —,
#  1852,
#  36,
#  first,
#  the Analytical Engine,
#  Swiss,
#  Jacob Bernoulli,
#  Walter Isaacson,
#  The Innovators,
#  British,
#  Lord Byron,
#  Romantic,
#  one,
#  Betty Alexandra Toole,
#  Lovelace,
#  the mid-20th century,
#  the Defense Department,
#  October,
#  Lady Lovelace,
#  The London Examiner,
#  Sciences,
#  Dec. 10, 1815,
#  London,
#  Annabella Milbanke,
#  8,
#  Medea,
#  Lovelace,
#  Smith Collection/Gado/Getty Images
#
#   Lovelace,
#  British,
#  the day,
#  Mary Somerville,
#  Somerville,
#  Lovelace to Babbage,
#  17,
#  two-foot,
#  almost two decades,
#  William King,
#  Somerville,
#  1835,
#  19,
#  the Countess of Lovelace,
#  1839,
#  two,
#  Somerville,
#  Trigonometry,
#  Cubic and Biquadratic Equations,
#  1840,
#  Lovelace,
#  Augustus De Morgan,
#  London,
#  first,
#  1843,
#  27,
#  Lovelace,
#  the Babbage Analytical Engine,
#  nearly three,
#  Notes,
#  first,
#  Ursula Martin,
#  the University of Oxford,
#  Lovelace’s,
#  less than a decade later,
#  Nov. 27, 1852,
#  Notes,
#  Claire Cain Miller,
#  Upshot,
#  first,
#  Ada Lovelace)

# %% [markdown]
# Each of the named entities in `document.ents` contains [more information about itself](https://spacy.io/usage/linguistic-features#accessing), which we can access by iterating through the `document.ents` with a simple `for` loop. `For` each `named_entity` in `document.ents`, we will extract the `named_entity` and its corresponding `named_entity.label_`.

# %%
for named_entity in document.ents:
    print(named_entity, named_entity.label_)
# Out:
# first ORDINAL
# Ada Lovelace PERSON
# 1843 DATE
# Jacquard GPE
# British NORP
# Charles Babbage’s PERSON
# Lovelace — WORK_OF_ART
# 1852 DATE
# 36 CARDINAL
# first ORDINAL
# the Analytical Engine ORG
# Swiss NORP
# Jacob Bernoulli PERSON
# Walter Isaacson PERSON
# The Innovators WORK_OF_ART
# British NORP
# Lord Byron PERSON
# Romantic NORP
# one CARDINAL
# Betty Alexandra Toole PERSON
# Lovelace PERSON
# the mid-20th century DATE
# the Defense Department ORG
# October DATE
# Lady Lovelace PERSON
# The London Examiner ORG
# Sciences ORG
# Dec. 10, 1815 DATE
# London GPE
# Annabella Milbanke PERSON
# 8 DATE
# Medea PERSON
# Lovelace PERSON
# Smith Collection/Gado/Getty Images
#
#  Lovelace ORG
# British NORP
# the day DATE
# Mary Somerville PERSON
# Somerville PERSON
# Lovelace to Babbage WORK_OF_ART
# 17 DATE
# two-foot QUANTITY
# almost two decades DATE
# William King PERSON
# Somerville ORG
# 1835 DATE
# 19 DATE
# the Countess of Lovelace FAC
# 1839 DATE
# two CARDINAL
# Somerville ORG
# Trigonometry GPE
# Cubic and Biquadratic Equations ORG
# 1840 DATE
# Lovelace PERSON
# Augustus De Morgan PERSON
# London GPE
# first ORDINAL
# 1843 DATE
# 27 DATE
# Lovelace PERSON
# the Babbage Analytical Engine ORG
# nearly three CARDINAL
# Notes PRODUCT
# first ORDINAL
# Ursula Martin PERSON
# the University of Oxford ORG
# Lovelace’s PERSON
# less than a decade later DATE
# Nov. 27, 1852 DATE
# Notes PRODUCT
# Claire Cain Miller PERSON
# Upshot ORG
# first ORDINAL
# Ada Lovelace PERSON

# %% [markdown]
# To extract just the named entities that have been identified as `PERSON`, we can add a simple `if` statement into the mix:

# %%
for named_entity in document.ents:
    if named_entity.label_ == "PERSON":
        print(named_entity)
# Out:
# Ada Lovelace
# Charles Babbage’s
# Jacob Bernoulli
# Walter Isaacson
# Lord Byron
# Betty Alexandra Toole
# Lovelace
# Lady Lovelace
# Annabella Milbanke
# Medea
# Lovelace
# Mary Somerville
# Somerville
# William King
# Lovelace
# Augustus De Morgan
# Lovelace
# Ursula Martin
# Lovelace’s
# Claire Cain Miller
# Ada Lovelace

# %% [markdown]
# # Practicing with *Lost in the City*

# %% [markdown]
# For the rest of this lesson, we're going to work with Edward P. Jones's short story collection *Lost in the City*.

# %% [markdown]
# <img src="https://mybinder.org/static/images/logo_social.png" width="150" align="left"> *If you're using this Jupyter notebook in Binder (in the cloud), please uncomment the cell below and work with only the first story from _Lost in the City_. The Binder notebook is currently having issues loading the entire collection.*

# %%
#file = "../texts/literature/Lost-in-the-City_Stories/01-The-Girl-Who-Raised-Pigeons.txt"
#document = nlp(open(file).read())

# %%
filepath = "../texts/literature/Jones-Lost-in-The-City.txt"
document = nlp(open(filepath, encoding="utf-8").read())

# %% [markdown]
# # Get People

# %% [markdown]
# |Type Label|Description|
# |:---:|:---:|
# |PERSON|People, including fictional.|

# %% [markdown]
# To extract and count the people identified in *Lost in the City*, we will follow the same model as above, using an `if` statement that will pull out words only if their "ent" label matches "PERSON."

# %% [markdown]
# > 🐍 **Python Review** 🐍
#
# >*While we demonstrate how to extract named entities in the sections below, we're also going to reinforce some integral Python skills. Notice how we use `for` loops and `if` statements to `.append()` specific words to a list. Then we count the words in the list and make a pandas dataframe from the list.*

# %% [markdown]
# Here's the code all together:

# %%
people = []
for named_entity in document.ents:
    if named_entity.label_ == "PERSON":
        people.append(named_entity.text)
        
people_tally = Counter(people)

df = pd.DataFrame(people_tally.most_common(), columns=['character', 'count'])
df

# %% [markdown]
# Here's the code broken up. We make a list of all the people identified in *Lost in the City*:

# %%
people = []
for named_entity in document.ents:
    if named_entity.label_ == "PERSON":
        people.append(named_entity.text)

# %%
people
# Out:
# ['Betsy Ann Morgan',
#  'Robert',
#  'Miles Patterson',
#  'Miles',
#  'Betsy Ann',
#  'Jenny',
#  'Robert',
#  'Betsy Ann',
#  'Betsy Ann',
#  'Miles',
#  'Buster',
#  'Betsy Ann',
#  'Miles',
#  'Miles',
#  'Betsy Ann’s',
#  'Betsy Ann',
#  'Betsy Ann',
#  'Walter Creed’s',
#  'Jenny',
#  'Creed',
#  'Miles',
#  'Miles',
#  'Miles Patterson',
#  'Miles',
#  'Jenny',
#  'Jenny Creed',
#  'Betsy Ann',
#  'Jenny’s',
#  'Robert Morgan',
#  'Jenny',
#  'Walter Creed',
#  'Jenny',
#  'Clara',
#  'Robert’s',
#  'Clara',
#  'Jenny',
#  'Clara',
#  'Robert',
#  'Jenny',
#  'Hahn',
#  'Jenny',
#  'William',
#  'Alice Hobson',
#  'Jenny',
#  'Clara',
#  'Robert',
#  'Clara',
#  'Jenny’s',
#  'Clara',
#  'Robert',
#  'Robert',
#  'Jenny',
#  'Jenny',
#  'Clara',
#  'Robert Morgan',
#  'Robert',
#  'Miss Jenny',
#  'Jenny',
#  'Clara',
#  'Robert',
#  'Robert',
#  'Clara',
#  'Robert',
#  'Clara',
#  'Robert',
#  'Jenny',
#  'Robert',
#  'Robert',
#  'Miss Jenny',
#  'Jenny',
#  'Jenny',
#  'Woulda',
#  'Jenny',
#  'Betsy Ann',
#  'Betsy Ann',
#  'Oscar Jackson',
#  'Jenny’s',
#  'Jake Horton',
#  'Robert Morgan',
#  'Jenny’s',
#  'Robert',
#  'Clara',
#  'Betsy Ann',
#  'Janet Gordon',
#  'Robert',
#  'Janet',
#  'Janet',
#  'Robert',
#  'Betsy Ann',
#  'Miles',
#  'Ralph Holley',
#  'Miles',
#  'Robert',
#  'Betsy Ann',
#  'Miles',
#  'Miles',
#  'Ralph',
#  'Miles',
#  'Ralph',
#  'Ralph',
#  'Ralph',
#  'Ralph',
#  'Aunt Thelma',
#  'Miles',
#  'Jenny',
#  'Betsy Ann',
#  'Miles',
#  'Betsy Ann',
#  'Robert',
#  'Robert',
#  'Miles',
#  'Ralph',
#  'Ralph',
#  'Betsy Ann',
#  'Esso',
#  'Ralph',
#  'Jenny',
#  'Jenny’s',
#  'Jenny',
#  'Betsy Ann',
#  'Betsy Ann',
#  'Jenny',
#  'Robert',
#  'Jenny’s',
#  'Bosco',
#  'Jenny',
#  'Jenny’s',
#  'Robert',
#  'Betsy Ann’s',
#  'Richard Nixon',
#  'Poison',
#  'LaDeidre Gordon',
#  'LaDeidre',
#  'Coo-Coo',
#  'LaDeidre',
#  'Betsy Ann',
#  'Ralph’s',
#  'Thelma Holley',
#  'Ralph',
#  'Thelma',
#  'Ralph',
#  'Ralph',
#  'Ralph',
#  'Betsy Ann',
#  'Ralph',
#  'Ralph’s',
#  'Betsy Ann',
#  'Ralph',
#  'Betsy Ann',
#  'Robert Morgan',
#  'Darlene Greenley',
#  'Betsy Ann',
#  'Jenny',
#  'Darlene',
#  'Darlene',
#  'Ralph’s',
#  'Darlene',
#  'Darlene',
#  'Betsy Ann',
#  'Darlene',
#  'Peoples',
#  'Betsy Ann',
#  'Darlene',
#  'Darlene',
#  'Betsy Ann',
#  'Etta O’Connell',
#  'Betsy Ann',
#  'Etta',
#  'Betsy Ann',
#  'Betsy Ann',
#  'Betsy Ann',
#  'Etta',
#  'Betsy Ann',
#  '’s',
#  'Betsy Ann’s',
#  'Child',
#  'Etta',
#  'Betsy Ann',
#  'Etta',
#  'Betsy Ann',
#  'Etta',
#  'Darlene',
#  'Darlene',
#  'Betsy Ann',
#  'Betsy Ann',
#  'Robert',
#  'Jenny',
#  'Jenny',
#  'Jenny',
#  'Robert',
#  'Janet Gordon',
#  'Howard',
#  'Janet',
#  'Jenny',
#  'Robert',
#  'Jenny',
#  'Betsy Ann',
#  'Betsy Ann',
#  'Walter',
#  'Betsy Ann',
#  'Robert',
#  'Robert',
#  'Betsy Ann',
#  'Jenny',
#  'Jenny',
#  'Walter',
#  'Walter',
#  'Robert',
#  'Betsy Ann',
#  'Jenny’s',
#  'Robert',
#  'Robert',
#  'Anacostia',
#  'Jenny',
#  'Robert',
#  'Clara',
#  'Betsy Ann',
#  'Robert',
#  'Betsy Ann’s',
#  'Jenny’s',
#  'Mary Keith',
#  'Blondelle Harris',
#  'Mary',
#  'Blondelle',
#  'Mary',
#  'Blondelle',
#  'Carmel Baptist',
#  'Ebony',
#  'Seaton',
#  'Ebony',
#  'Cassandra G. Lewis',
#  'Chesterfields',
#  'Cassandra',
#  'Hollywood Hudson',
#  'Cassandra',
#  'Bartlett',
#  'Bartlett',
#  'Rhonda Ferguson',
#  'Cassandra',
#  'Rhonda Ferguson',
#  'Rhonda',
#  'Clifton',
#  'Rhonda',
#  'Rhonda',
#  'Cassandra',
#  'Rhonda',
#  'Cassandra',
#  'Alice',
#  'Ferguson',
#  'Cassandra',
#  'Alice',
#  'Jeffrey',
#  'Cassandra',
#  'Rhonda',
#  'Afro',
#  'Cassandra',
#  'Rhonda',
#  'Rhonda',
#  'Rhonda',
#  'Alice',
#  'Rhonda',
#  'Rhonda',
#  'Ferguson',
#  'Rhonda',
#  'Jeffrey Stanford',
#  'Rhonda',
#  'Mabel',
#  'Rhonda',
#  'Cassandra',
#  'Rhonda',
#  'Rhonda',
#  'Cassandra',
#  'Melanie Cartwright',
#  'Melanie',
#  'Viceroys',
#  'Melanie',
#  'Melanie',
#  'Cassandra',
#  'Melanie',
#  'Anita Hughes',
#  'Cassandra',
#  'Barlett',
#  'Cassandra',
#  'Anita',
#  'Anita',
#  'Anita',
#  'Willie’s',
#  'Melanie',
#  'Melanie',
#  'Anita',
#  'Cassandra',
#  'Willie',
#  'Melanie',
#  'Gladys Harper',
#  'Cassandra',
#  'Gladys',
#  'Anita',
#  'Gladys',
#  'Melanie',
#  'Gladys',
#  'Anacostia',
#  'Cassandra',
#  'Gladys',
#  'Anita',
#  'Melanie',
#  'Melanie',
#  'Gladys',
#  'Cassandra',
#  'Gladys',
#  'Anita',
#  'Melanie',
#  'Cassandra',
#  'Mildred Harper',
#  'Anita',
#  'Melanie',
#  'Mildred Harper',
#  'Cassandra',
#  'Cassandra',
#  'Anita',
#  'Mildred Harper',
#  'Melanie',
#  'Cassandra',
#  'Melanie',
#  'Guy',
#  'Sing',
#  'Sing',
#  'Cassandra',
#  'Rhonda',
#  'Anita',
#  'Cassandra',
#  'Rhonda',
#  'Melanie',
#  'Cassandra',
#  'Rhonda',
#  'Melanie',
#  'Cassandra',
#  'Cassandra',
#  'Melanie',
#  'Sing',
#  'Melanie',
#  'Anita',
#  'Guy',
#  'Melanie',
#  'Cassandra',
#  'Gladys',
#  'Cassandra',
#  'Joyce',
#  'Pearl',
#  'Cassandra',
#  'Gladys',
#  'Joyce Moses',
#  'Joyce Moses',
#  'Pearl Guthrie',
#  'Gladys',
#  'Pearl',
#  'Cassandra',
#  'Joyce',
#  'Joyce',
#  'Melanie',
#  'Anita',
#  'Joyce',
#  'Pearl',
#  'Gladys',
#  'Joyce',
#  'Pearl',
#  'Gladys',
#  'Joyce',
#  'Joyce',
#  'Pearl',
#  'Joyce',
#  'Joyce',
#  'Pearl',
#  'Pearl',
#  'Joyce',
#  'Hush',
#  'Hush',
#  'Cassandra',
#  'Rufus',
#  'Dwayne',
#  'Melanie',
#  'Kelvin',
#  'Gladys',
#  'Cassandra',
#  'Anacostia',
#  'Melanie',
#  'Dwayne',
#  'Cassandra',
#  'Anita',
#  'Gladys',
#  'Dwayne',
#  'Melanie',
#  'Anita',
#  'Gladys',
#  'Anita',
#  'Cassandra',
#  'Anita',
#  'Rhonda',
#  'Cassandra',
#  'Melanie',
#  'Rhonda',
#  'Anita',
#  'Gladys',
#  'Melanie',
#  'Cassandra',
#  'Melanie',
#  'Gladys',
#  'Melanie',
#  'Anita',
#  'Cassandra',
#  'Anita',
#  'Anacostia',
#  'Anacostia',
#  'Anita',
#  'Cassandra',
#  'Gladys',
#  'Anita',
#  'Glady',
#  'Anita',
#  'Cassandra',
#  'Melanie',
#  'Cassandra',
#  'Engaged',
#  'Melanie',
#  'Gladys',
#  'Cassandra',
#  'Anita',
#  'Cassandra',
#  'Anita',
#  'Cassandra',
#  'Gladys',
#  'Honey',
#  'Honey',
#  'Honey',
#  'Melanie',
#  'Cassandra',
#  'Melanie',
#  'Anita',
#  'Gladys',
#  'Cassandra',
#  'Melanie',
#  'Cassandra',
#  'Melanie',
#  'Gladys',
#  'Anita',
#  'Melanie',
#  'Cassandra',
#  'Cassandra',
#  'Anita’s',
#  'Cassandra',
#  'Melanie',
#  'Gladys',
#  'Bama',
#  'Wesley',
#  'Cassandra',
#  'Anita',
#  'Anita',
#  'Melanie',
#  'Gladys',
#  'Wesley',
#  'Cassandra',
#  'Wesley',
#  'Cassandra',
#  'Wesley',
#  'Cassandra',
#  'Wesley',
#  'Cassandra',
#  'Wesley',
#  'Bob',
#  'Cassandra',
#  'Cassandra',
#  'Cassandra',
#  'Wesley',
#  'Melanie',
#  'Anita',
#  'Gladys',
#  'Cassandra',
#  'Melanie',
#  'Cassandra',
#  'Cassandra',
#  'Wesley',
#  'Lady',
#  'Wesley',
#  'Cassandra',
#  'Melanie',
#  'Roger',
#  'Melanie',
#  'Roger',
#  'Wesley',
#  'Roger',
#  'Roger',
#  'Melanie',
#  'Wesley',
#  'Cassandra',
#  'Melanie',
#  'Anita',
#  'Melanie',
#  'Cassandra',
#  'Melanie',
#  'Melanie',
#  'Cassandra',
#  'Cassandra',
#  'Melanie',
#  'Dwayne',
#  'Melanie',
#  'Cassandra',
#  'Melanie',
#  'Dwayne',
#  'Cassandra',
#  'Melanie',
#  'Cassandra',
#  'Melanie',
#  'Anita',
#  'Gladys',
#  'Melanie',
#  'Gladys',
#  'Anita',
#  'Cassandra',
#  'Melanie',
#  'Anita',
#  'Melanie',
#  'Gladys',
#  'Melanie',
#  'Anita',
#  'Melanie',
#  'Cassandra',
#  'Cassandra',
#  'Cassandra',
#  'Melanie',
#  'Melanie',
#  'Cassandra',
#  'Anita',
#  'Cassandra',
#  'Cassandra',
#  'Anita',
#  'Cassandra',
#  'Cassandra',
#  'Cassandra',
#  'Anita',
#  'Melanie',
#  'Gladys',
#  'Gladys',
#  'Melanie',
#  'Melanie',
#  'Anita',
#  'Gladys',
#  'Melanie',
#  'Guy',
#  'Melanie',
#  'Cassandra',
#  'Anita',
#  'Cassandra',
#  'Anita',
#  'Anita',
#  'Gladys',
#  'Anita',
#  'Anita',
#  'Anita',
#  'Cassandra',
#  'Cassandra',
#  'Anita',
#  'Melanie',
#  'Anita',
#  'Anita',
#  'Anita',
#  'Jeffrey',
#  'Rhonda',
#  'Jeffrey',
#  'Rhonda',
#  'Cassandra',
#  'Cassandra',
#  'Honey',
#  'Anita',
#  'Cassandra',
#  'Rhonda',
#  'Anita',
#  'Anita',
#  'Cassandra',
#  'Cassandra',
#  'Melanie',
#  'Cassandra',
#  'Cassandra',
#  'Clifton Terrace',
#  'Anita',
#  'Melanie',
#  'Anita',
#  'Anita',
#  'Cassandra',
#  'Anita',
#  'Cassandra',
#  'Anita',
#  'Anita',
#  'Anita',
#  'Cassandra',
#  'Cassandra',
#  'Anita',
#  'Anita',
#  'Cassandra',
#  'Anita',
#  'Cassandra',
#  'Cassandra',
#  'Anita',
#  'Anita',
#  'Anita',
#  'Cassandra',
#  'Anita',
#  'Carol',
#  'Manny',
#  'Manny Soto',
#  'Manny',
#  'Sherman',
#  'Heh',
#  'Manny',
#  'Manny',
#  'Sherman',
#  'Manny',
#  'Sherman',
#  'Howard Hospital',
#  'Carol',
#  'Sandra Wallington',
#  'Sandra',
#  'Sherman',
#  'Sandra',
#  'Carol',
#  'Carol',
#  'Carol',
#  'Carol',
#  'Sherman',
#  'Sherman Wheeler',
#  'Sherman',
#  'Manny',
#  'Manny',
#  'Manny',
#  'Manny',
#  'Manny',
#  'Manny',
#  'Manny',
#  'Young Blood',
#  'Manny',
#  'Sherman',
#  'Manny',
#  'Manny',
#  'Manny',
#  'Manny',
#  'Manny',
#  'Sherman',
#  'Manny',
#  'Manny',
#  'Manny',
#  'Sherman',
#  'Sherman',
#  'ODed',
#  'Manny',
#  'Manny',
#  'Manny',
#  'Manny',
#  'Sandra',
#  'Sandra',
#  'Sherman',
#  'Sherman',
#  'Sherman',
#  'Sherman',
#  'Manny',
#  'Bet',
#  'Sherman',
#  'Polaroid',
#  'Sherman',
#  'Manny',
#  'Manny',
#  'Manny’s',
#  'Sherman',
#  'Manny',
#  'Manny',
#  'Manny',
#  'Carol',
#  'Sherman',
#  'Sherman',
#  'Sherman',
#  'Fred',
#  'Fred',
#  'Prentiss',
#  'Prentiss',
#  'Anna',
#  'Elsie',
#  'Carol',
#  'Sherman',
#  'Sherman',
#  'Carol',
#  'Anna',
#  'Carol',
#  'Angelo Billings',
#  'Angelo',
#  'Sherman',
#  'Angelo',
#  'Sherman',
#  'Angelo',
#  'Sherman',
#  'Angelo',
#  'Angelo',
#  'Caesar',
#  'Sherman',
#  'Lemuel Matthews’s',
#  'Sherman',
#  'Sandra',
#  'Sherman',
#  '’s',
#  'Angelo',
#  'Sherman',
#  'Angelo',
#  'Angelo',
#  'Caesar',
#  'Sherman',
#  'Sherman',
#  'Sherman',
#  'Sherman',
#  'Sherman',
#  'Sherman',
#  'Sherman',
#  'Sherman',
#  'Sherman',
#  'Carol',
#  'Sherman',
#  'Sherman',
#  'Sherman',
#  'Sherman',
#  'Anna',
#  'Carol',
#  'Sherman',
#  'Carol',
#  'Manny',
#  'Carol',
#  'Manny',
#  'Carol',
#  'Burberry Carol',
#  'Anna',
#  'Carol',
#  'Carol',
#  'Adam',
#  'Anna',
#  'Carol',
#  'Anna',
#  'Carol',
#  'Anna',
#  'Carol',
#  'Sherman',
#  'Anna',
#  'Anna',
#  'Sherman',
#  'Anna',
#  'Sherman',
#  'Sherman',
#  'Carol',
#  'Anna',
#  'Anna',
#  'Carol',
#  'Anna',
#  'Carol',
#  'Carol',
#  'Jesus',
#  'Carol',
#  'Atlas',
#  'Lonney McCrae',
#  'Lonney',
#  'Howard',
#  'Kennedy',
#  'Lonney',
#  'Brenda Roper',
#  'Lonney',
#  'Brenda',
#  'Lonney',
#  'Brenda',
#  'McCrae',
#  'Lonney',
#  'Brenda',
#  'Brenda',
#  'Brenda',
#  '’s Penelope Jenkins',
#  'Penny',
#  'Jenkins',
#  'Jenkins',
#  'Jenkins',
#  'Jenkins',
#  'Jenkins',
#  'Mabel Smith',
#  'Lonney',
#  'Brenda',
#  'Mabel',
#  'Brenda',
#  'Jenkins',
#  'Jenkins',
#  'Jenkins',
#  'Jenkins',
#  'Lonney',
#  'Brenda',
#  '’s',
#  'Jenkins',
#  'Jenkins',
#  'Gertrude Baxter—',
#  'Turner',
#  'Gimme',
#  'Jenkins',
#  'Baxter',
#  'Penny Jenkins',
#  'Jenkins',
#  'Patricia',
#  'Ohh',
#  'Tommy',
#  'Jenkins',
#  'Patricia',
#  'Jenkins',
#  'Patricia',
#  'Jenkins',
#  'Fort Holabird',
#  'Penny',
#  'Penny',
#  'Howard Theater',
#  'Dinah Washington',
#  'Dinah Washington',
#  'Mile Long',
#  'Thou',
#  'Knight',
#  'Dixie Peach',
#  'Stanback',
#  'Bat',
#  'Wonder Bread',
#  'Penelope Jenkins',
#  'Al Jenkins',
#  'Al',
#  'Penny',
#  'O. Lonney',
#  'Penny',
#  'Penny',
#  'Al Jenkins',
#  'Al',
#  'Joy Lambert',
#  'Patricia',
#  'Tommy Turner',
#  'Joy',
#  'Al',
#  'Joy',
#  'Penny',
#  'Kentucky',
#  'Penny',
#  'N',
#  'Penny',
#  'Penny',
#  'Carter',
#  'Penny',
#  'Penny',
#  'Penny',
#  'Penny',
#  'Penny',
#  'Penny',
#  'Carl Baggot',
#  'Penny',
#  'Tommy Turner',
#  'Patricia Turner',
#  'Hula Hoop',
#  'Baxter',
#  'Penny',
#  'Baxter',
#  'Tommy',
#  'Penny',
#  'Penny',
#  'Patricia',
#  'Soon Joy',
#  'Penny',
#  'Tommy',
#  'Tommy',
#  'Penny',
#  'Penny',
#  'Snowball Patterson',
#  'Baxter',
#  'Penny',
#  'Patricia',
#  'Penny',
#  'Pat’s',
#  'Penny',
#  'Penny',
#  'Penny',
#  'Baxter',
#  'Penny',
#  'Joy',
#  'Pat',
#  'Tommy',
#  'Joy',
#  'Penny',
#  'Penny',
#  'Penny',
#  'Penny',
#  'Penny',
#  'Baxter',
#  'Penny',
#  'Lady Baxter',
#  'Baxter',
#  'Baxter',
#  'Penny',
#  'Penny',
#  'Penny',
#  'Penny',
#  'Kemo Sabe',
#  'Joy',
#  'Tommy',
#  'Tommy',
#  'Baxter',
#  'Penny',
#  'Afro',
#  'Penny',
#  'Penny',
#  'Penny',
#  'Penny',
#  'Severin',
#  'Pat',
#  'Velle” Watkins',
#  'Avis',
#  'Marvin',
#  'Marvin',
#  'Avis',
#  'Marvella',
#  'Marvin',
#  'Marvin',
#  'Avis',
#  'Marvella',
#  'Marvella',
#  'Avis',
#  'Marcus',
#  'Avis',
#  'Marvin',
#  'Marvin',
#  'Ballston',
#  'Marcus',
#  'Avis',
#  'Marvella',
#  'Marcus',
#  'Avis',
#  'Avis',
#  'Avis',
#  'Marvella',
#  'Ballston',
#  'Marvella',
#  'Marvin',
#  'Marvin',
#  'Marcus',
#  'Avis',
#  'Marvella',
#  'Marcus',
#  'Avis',
#  'Marvella',
#  'Avis',
#  'Marvin',
#  'Avis',
#  'Avis',
#  'Marvella',
#  'Avis',
#  'Avis',
#  'Marcus',
#  'Marvin',
#  'Ballston',
#  'Marvella',
#  'Ballston',
#  'Avis',
#  'Marvin',
#  'Marvin',
#  'Marvin',
#  'Capricorns',
#  'Libras',
#  'Marvin',
#  'Marcus',
#  'Ballston',
#  'Avis',
#  'Marcus',
#  '’s Ballston',
#  'Kinda',
#  'Marcus',
#  'Avis',
#  'Marvella',
#  'Marvin',
#  'Avis',
#  'Marcus',
#  'Avis',
#  'Marvella',
#  'Avis',
#  'Avis',
#  'Marvin',
#  'Marvin',
#  'Marvella',
#  'Avis',
#  'Marvin',
#  'Marvin',
#  'Marvin',
#  'Marvin',
#  'Marvella',
#  'Marvin',
#  'Marcus',
#  'Marvin',
#  'Avis',
#  'Marvin',
#  'Marcus',
#  'Avis',
#  'Marcus',
#  'Avis',
#  ...]

# %% [markdown]
# Then we count the unique people in this list with the `Counter()` module:

# %%
people_tally = Counter(people)

# %%
people_tally.most_common()
# Out:
# [('Cassandra', 97),
#  ('Anita', 88),
#  ('Joyce', 82),
#  ('Melanie', 65),
#  ('Rickey', 57),
#  ('Woodrow', 54),
#  ('Sherman', 47),
#  ('Marie', 45),
#  ('Penny', 44),
#  ('Betsy Ann', 40),
#  ('Madeleine', 40),
#  ('Diane', 38),
#  ('Samuel', 37),
#  ('Garrett', 37),
#  ('Gladys', 33),
#  ('Manny', 33),
#  ('Sam', 33),
#  ('Robert', 31),
#  ('Jenny', 30),
#  ('Humphrey', 30),
#  ('Avis', 27),
#  ('Maddie', 26),
#  ('Carol', 25),
#  ('Pearl', 24),
#  ('Marvin', 24),
#  ('Maude', 24),
#  ('Rhonda', 23),
#  ('Ralph', 21),
#  ('Jenkins', 16),
#  ('Miles', 15),
#  ('Sandy', 15),
#  ('Mildred', 15),
#  ('Rita', 15),
#  ('Marvella', 14),
#  ('Anacostia', 13),
#  ('Anna', 13),
#  ('Marcus', 13),
#  ('Clara', 12),
#  ('Jesus', 12),
#  ('Wesley', 11),
#  ('Adam', 11),
#  ('John Henry', 10),
#  ('Jenny’s', 9),
#  ('Darlene', 9),
#  ('Baxter', 9),
#  ('Smokey', 9),
#  ('’s', 8),
#  ('Alice', 8),
#  ('Angelo', 8),
#  ('Brenda', 8),
#  ('Lydia', 8),
#  ('Saunders', 8),
#  ('Lonney', 7),
#  ('Tommy', 7),
#  ('Joe', 7),
#  ('Patricia', 6),
#  ('Hazel', 6),
#  ('Mama Joyce', 6),
#  ('Clovis', 6),
#  ('Taylor', 6),
#  ('Etta', 5),
#  ('Sing', 5),
#  ('Dwayne', 5),
#  ('Sandra', 5),
#  ('Joy', 5),
#  ('Ballston', 5),
#  ('Clarine', 5),
#  ('Betsy Ann’s', 4),
#  ('Robert Morgan', 4),
#  ('Mildred Harper', 4),
#  ('Honey', 4),
#  ('Roger', 4),
#  ('Pookie', 4),
#  ('Antibes', 4),
#  ('Jesse Mae', 4),
#  ('Elaine', 4),
#  ('Sawyer', 4),
#  ('Bea', 4),
#  ('Smith', 4),
#  ('John Smith', 4),
#  ('Janet', 3),
#  ('Ralph’s', 3),
#  ('Walter', 3),
#  ('Jeffrey', 3),
#  ('Guy', 3),
#  ('Joyce Moses', 3),
#  ('Lady', 3),
#  ('Al', 3),
#  ('Jr.', 3),
#  ('Williams', 3),
#  ('Walsh', 3),
#  ('Mansfield', 3),
#  ('Harry', 3),
#  ('Cherry', 3),
#  ('John', 3),
#  ('Fur', 3),
#  ('Woodrow L. Cunningham', 3),
#  ('Lani', 3),
#  ('Beatrice', 3),
#  ('Green', 3),
#  ('George', 3),
#  ('Nicodemus', 3),
#  ('Loretta', 3),
#  ('Miles Patterson', 2),
#  ('William', 2),
#  ('Miss Jenny', 2),
#  ('Janet Gordon', 2),
#  ('LaDeidre', 2),
#  ('Howard', 2),
#  ('Mary', 2),
#  ('Blondelle', 2),
#  ('Ebony', 2),
#  ('Bartlett', 2),
#  ('Rhonda Ferguson', 2),
#  ('Ferguson', 2),
#  ('Afro', 2),
#  ('Mabel', 2),
#  ('Anita Hughes', 2),
#  ('Hush', 2),
#  ('Fred', 2),
#  ('Prentiss', 2),
#  ('Caesar', 2),
#  ('Gimme', 2),
#  ('Dinah Washington', 2),
#  ('Mile Long', 2),
#  ('Al Jenkins', 2),
#  ('Tommy Turner', 2),
#  ('Pat', 2),
#  ('Madeleine Williams', 2),
#  ('Sam Williams', 2),
#  ('Samuel Williams', 2),
#  ('Tellingford', 2),
#  ('Martin Luther King', 2),
#  ('Watts', 2),
#  ('Gail', 2),
#  ('Lydia Walsh', 2),
#  ('George Washington', 2),
#  ('Jack Lawrence', 2),
#  ('Cynthia', 2),
#  ('Cornelia', 2),
#  ('Chatty Cathy', 2),
#  ('Santiago Moses', 2),
#  ('Rickey Madison', 2),
#  ('Gettin', 2),
#  ('Santiago', 2),
#  ('Chuck Taylor', 2),
#  ('Yall', 2),
#  ('Potomac', 2),
#  ('Thas', 2),
#  ('Diane McCollough', 2),
#  ('Counsel Smith', 2),
#  ('Ooh', 2),
#  ('Jesse Mae Carson', 2),
#  ('Ritter', 2),
#  ('Cunningham', 2),
#  ('Elaine Cunningham', 2),
#  ('Rita Hadley', 2),
#  ('Doin', 2),
#  ('Dora', 2),
#  ('Uncle Ray’s', 2),
#  ('Ray', 2),
#  ('Aunt Ebbie’s', 2),
#  ('Lightnin', 2),
#  ('Calhoun', 2),
#  ('Calhoun Lambeth', 2),
#  ('Brown', 2),
#  ('George Carter', 2),
#  ('Granddaddy', 2),
#  ('Betsy Ann Morgan', 1),
#  ('Buster', 1),
#  ('Walter Creed’s', 1),
#  ('Creed', 1),
#  ('Jenny Creed', 1),
#  ('Walter Creed', 1),
#  ('Robert’s', 1),
#  ('Hahn', 1),
#  ('Alice Hobson', 1),
#  ('Woulda', 1),
#  ('Oscar Jackson', 1),
#  ('Jake Horton', 1),
#  ('Ralph Holley', 1),
#  ('Aunt Thelma', 1),
#  ('Esso', 1),
#  ('Bosco', 1),
#  ('Richard Nixon', 1),
#  ('Poison', 1),
#  ('LaDeidre Gordon', 1),
#  ('Coo-Coo', 1),
#  ('Thelma Holley', 1),
#  ('Thelma', 1),
#  ('Darlene Greenley', 1),
#  ('Peoples', 1),
#  ('Etta O’Connell', 1),
#  ('Child', 1),
#  ('Mary Keith', 1),
#  ('Blondelle Harris', 1),
#  ('Carmel Baptist', 1),
#  ('Seaton', 1),
#  ('Cassandra G. Lewis', 1),
#  ('Chesterfields', 1),
#  ('Hollywood Hudson', 1),
#  ('Clifton', 1),
#  ('Jeffrey Stanford', 1),
#  ('Melanie Cartwright', 1),
#  ('Viceroys', 1),
#  ('Barlett', 1),
#  ('Willie’s', 1),
#  ('Willie', 1),
#  ('Gladys Harper', 1),
#  ('Pearl Guthrie', 1),
#  ('Rufus', 1),
#  ('Kelvin', 1),
#  ('Glady', 1),
#  ('Engaged', 1),
#  ('Anita’s', 1),
#  ('Bama', 1),
#  ('Bob', 1),
#  ('Clifton Terrace', 1),
#  ('Manny Soto', 1),
#  ('Heh', 1),
#  ('Howard Hospital', 1),
#  ('Sandra Wallington', 1),
#  ('Sherman Wheeler', 1),
#  ('Young Blood', 1),
#  ('ODed', 1),
#  ('Bet', 1),
#  ('Polaroid', 1),
#  ('Manny’s', 1),
#  ('Elsie', 1),
#  ('Angelo Billings', 1),
#  ('Lemuel Matthews’s', 1),
#  ('Burberry Carol', 1),
#  ('Atlas', 1),
#  ('Lonney McCrae', 1),
#  ('Kennedy', 1),
#  ('Brenda Roper', 1),
#  ('McCrae', 1),
#  ('’s Penelope Jenkins', 1),
#  ('Mabel Smith', 1),
#  ('Gertrude Baxter—', 1),
#  ('Turner', 1),
#  ('Penny Jenkins', 1),
#  ('Ohh', 1),
#  ('Fort Holabird', 1),
#  ('Howard Theater', 1),
#  ('Thou', 1),
#  ('Knight', 1),
#  ('Dixie Peach', 1),
#  ('Stanback', 1),
#  ('Bat', 1),
#  ('Wonder Bread', 1),
#  ('Penelope Jenkins', 1),
#  ('O. Lonney', 1),
#  ('Joy Lambert', 1),
#  ('Kentucky', 1),
#  ('N', 1),
#  ('Carter', 1),
#  ('Carl Baggot', 1),
#  ('Patricia Turner', 1),
#  ('Hula Hoop', 1),
#  ('Soon Joy', 1),
#  ('Snowball Patterson', 1),
#  ('Pat’s', 1),
#  ('Lady Baxter', 1),
#  ('Kemo Sabe', 1),
#  ('Severin', 1),
#  ('Velle” Watkins', 1),
#  ('Capricorns', 1),
#  ('Libras', 1),
#  ('’s Ballston', 1),
#  ('Kinda', 1),
#  ('Carlson', 1),
#  ('Samuel Lamont Williams', 1),
#  ('Agnes Marie Williams', 1),
#  ('John Tellingford', 1),
#  ('Larry', 1),
#  ('Maddie Williams', 1),
#  ('Aggie', 1),
#  ('Pookie Williams', 1),
#  ('Washton', 1),
#  ('Afros', 1),
#  ('Clarine’s', 1),
#  ('Bo Cromwell', 1),
#  ('Sam Wallace', 1),
#  ('Martha Eliot Infirmary', 1),
#  ('Nilla Wafers', 1),
#  ('the Martin Luther King', 1),
#  ('Hazel Watts', 1),
#  ('’s Maddie', 1),
#  ('D Ward', 1),
#  ('Clement', 1),
#  ('Arnisa Isaacs', 1),
#  ('Knew', 1),
#  ('Bill', 1),
#  ('JL', 1),
#  ('Gyn', 1),
#  ('Kaufman', 1),
#  ('Life Bst', 1),
#  ('Woolf', 1),
#  ('Yale Law', 1),
#  ('Gail Saunders', 1),
#  ('Amer', 1),
#  ('Ayn Rand', 1),
#  ('Je m’appelle Lydia', 1),
#  ('Trust Capitol', 1),
#  ('Empire', 1),
#  ('Joseph’s', 1),
#  ('Cab Driver', 1),
#  ('Eve', 1),
#  ('John Brown', 1),
#  ('Night', 1),
#  ('Range Rover', 1),
#  ('C’mon', 1),
#  ('Sooner', 1),
#  ('Pearl Malone', 1),
#  ('Pearl’s', 1),
#  ('Whas', 1),
#  ('Sweet Jesus', 1),
#  ('Sandy’d', 1),
#  ('Shoulda', 1),
#  ('Peebles', 1),
#  ('Smokey Peebles', 1),
#  ('Chuck', 1),
#  ('Rickey’s', 1),
#  ('Frankenstein', 1),
#  ('Clovis’s', 1),
#  ('Joyce’s', 1),
#  ('Jesus Christ', 1),
#  ('Place', 1),
#  ('Morton', 1),
#  ('’s Elizabeth Ann Coleman', 1),
#  ('Vivian L. Slater', 1),
#  ('Slater', 1),
#  ('Avenue', 1),
#  ('Sister Slater', 1),
#  ('Maude Townsend', 1),
#  ('Counsel', 1),
#  ('Melvin Ritter', 1),
#  ('Louis Ritter', 1),
#  ('Heavenly Choir', 1),
#  ('Jordan—\n\n\n\n', 1),
#  ('Forever Yours', 1),
#  ('Louis Ritter’s', 1),
#  ('Mahalia Jackson', 1),
#  ('Gospelteers', 1),
#  ('Jesus Met', 1),
#  ('Grace', 1),
#  ('’s Harry', 1),
#  ('Thomas Circle', 1),
#  ('Ralph Slater', 1),
#  ('Sister Rita', 1),
#  ('Rita’s', 1),
#  ('Rita the', 1),
#  ('Cunninghams', 1),
#  ('Petworth', 1),
#  ('Lincoln Park', 1),
#  ('Sparky', 1),
#  ('Easter', 1),
#  ('Raleigh', 1),
#  ('Ida Garrett', 1),
#  ('Beatrice Atwell’s', 1),
#  ('Fraziers', 1),
#  ('Jackleg', 1),
#  ('Sewin', 1),
#  ('Makin', 1),
#  ('Frazier', 1),
#  ('Arthur', 1),
#  ('Uncle', 1),
#  ('Uncle Joe', 1),
#  ('Ebbie', 1),
#  ('Uncle Ray', 1),
#  ('Joseph', 1),
#  ('Dickinson', 1),
#  ('Marie Delaveaux Wilson', 1),
#  ('John Smith’s', 1),
#  ('White', 1)]

# %% [markdown]
# Then we make a dataframe from this list with `pd.DataFrame()`:

# %%
df = pd.DataFrame(people_tally.most_common(), columns=['character', 'count'])
df
# Out:
#                     character  count
# 0                   Cassandra     97
# 1                       Anita     88
# 2                       Joyce     82
# 3                     Melanie     65
# 4                      Rickey     57
# 5                     Woodrow     54
# 6                     Sherman     47
# 7                       Marie     45
# 8                       Penny     44
# 9                   Betsy Ann     40
# 10                  Madeleine     40
# 11                      Diane     38
# 12                     Samuel     37
# 13                    Garrett     37
# 14                     Gladys     33
# 15                      Manny     33
# 16                        Sam     33
# 17                     Robert     31
# 18                      Jenny     30
# 19                   Humphrey     30
# 20                       Avis     27
# 21                     Maddie     26
# 22                      Carol     25
# 23                      Pearl     24
# 24                     Marvin     24
# 25                      Maude     24
# 26                     Rhonda     23
# 27                      Ralph     21
# 28                    Jenkins     16
# 29                      Miles     15
# 30                      Sandy     15
# 31                    Mildred     15
# 32                       Rita     15
# 33                   Marvella     14
# 34                  Anacostia     13
# 35                       Anna     13
# 36                     Marcus     13
# 37                      Clara     12
# 38                      Jesus     12
# 39                     Wesley     11
# 40                       Adam     11
# 41                 John Henry     10
# 42                    Jenny’s      9
# 43                    Darlene      9
# 44                     Baxter      9
# 45                     Smokey      9
# 46                         ’s      8
# 47                      Alice      8
# 48                     Angelo      8
# 49                     Brenda      8
# 50                      Lydia      8
# 51                   Saunders      8
# 52                     Lonney      7
# 53                      Tommy      7
# 54                        Joe      7
# 55                   Patricia      6
# 56                      Hazel      6
# 57                 Mama Joyce      6
# 58                     Clovis      6
# 59                     Taylor      6
# 60                       Etta      5
# 61                       Sing      5
# 62                     Dwayne      5
# 63                     Sandra      5
# 64                        Joy      5
# 65                   Ballston      5
# 66                    Clarine      5
# 67                Betsy Ann’s      4
# 68              Robert Morgan      4
# 69             Mildred Harper      4
# 70                      Honey      4
# 71                      Roger      4
# 72                     Pookie      4
# 73                    Antibes      4
# 74                  Jesse Mae      4
# 75                     Elaine      4
# 76                     Sawyer      4
# 77                        Bea      4
# 78                      Smith      4
# 79                 John Smith      4
# 80                      Janet      3
# 81                    Ralph’s      3
# 82                     Walter      3
# 83                    Jeffrey      3
# 84                        Guy      3
# 85                Joyce Moses      3
# 86                       Lady      3
# 87                         Al      3
# 88                        Jr.      3
# 89                   Williams      3
# 90                      Walsh      3
# 91                  Mansfield      3
# 92                      Harry      3
# 93                     Cherry      3
# 94                       John      3
# 95                        Fur      3
# 96      Woodrow L. Cunningham      3
# 97                       Lani      3
# 98                   Beatrice      3
# 99                      Green      3
# 100                    George      3
# 101                 Nicodemus      3
# 102                   Loretta      3
# 103           Miles Patterson      2
# 104                   William      2
# 105                Miss Jenny      2
# 106              Janet Gordon      2
# 107                  LaDeidre      2
# 108                    Howard      2
# 109                      Mary      2
# 110                 Blondelle      2
# 111                     Ebony      2
# 112                  Bartlett      2
# 113           Rhonda Ferguson      2
# 114                  Ferguson      2
# 115                      Afro      2
# 116                     Mabel      2
# 117              Anita Hughes      2
# 118                      Hush      2
# 119                      Fred      2
# 120                  Prentiss      2
# 121                    Caesar      2
# 122                     Gimme      2
# 123          Dinah Washington      2
# 124                 Mile Long      2
# 125                Al Jenkins      2
# 126              Tommy Turner      2
# 127                       Pat      2
# 128        Madeleine Williams      2
# 129              Sam Williams      2
# 130           Samuel Williams      2
# 131               Tellingford      2
# 132        Martin Luther King      2
# 133                     Watts      2
# 134                      Gail      2
# 135               Lydia Walsh      2
# 136         George Washington      2
# 137             Jack Lawrence      2
# 138                   Cynthia      2
# 139                  Cornelia      2
# 140              Chatty Cathy      2
# 141            Santiago Moses      2
# 142            Rickey Madison      2
# 143                    Gettin      2
# 144                  Santiago      2
# 145              Chuck Taylor      2
# 146                      Yall      2
# 147                   Potomac      2
# 148                      Thas      2
# 149          Diane McCollough      2
# 150             Counsel Smith      2
# 151                       Ooh      2
# 152          Jesse Mae Carson      2
# 153                    Ritter      2
# 154                Cunningham      2
# 155         Elaine Cunningham      2
# 156               Rita Hadley      2
# 157                      Doin      2
# 158                      Dora      2
# 159               Uncle Ray’s      2
# 160                       Ray      2
# 161              Aunt Ebbie’s      2
# 162                  Lightnin      2
# 163                   Calhoun      2
# 164           Calhoun Lambeth      2
# 165                     Brown      2
# 166             George Carter      2
# 167                Granddaddy      2
# 168          Betsy Ann Morgan      1
# 169                    Buster      1
# 170            Walter Creed’s      1
# 171                     Creed      1
# 172               Jenny Creed      1
# 173              Walter Creed      1
# 174                  Robert’s      1
# 175                      Hahn      1
# 176              Alice Hobson      1
# 177                    Woulda      1
# 178             Oscar Jackson      1
# 179               Jake Horton      1
# 180              Ralph Holley      1
# 181               Aunt Thelma      1
# 182                      Esso      1
# 183                     Bosco      1
# 184             Richard Nixon      1
# 185                    Poison      1
# 186           LaDeidre Gordon      1
# 187                   Coo-Coo      1
# 188             Thelma Holley      1
# 189                    Thelma      1
# 190          Darlene Greenley      1
# 191                   Peoples      1
# 192            Etta O’Connell      1
# 193                     Child      1
# 194                Mary Keith      1
# 195          Blondelle Harris      1
# 196            Carmel Baptist      1
# 197                    Seaton      1
# 198        Cassandra G. Lewis      1
# 199             Chesterfields      1
# 200          Hollywood Hudson      1
# 201                   Clifton      1
# 202          Jeffrey Stanford      1
# 203        Melanie Cartwright      1
# 204                  Viceroys      1
# 205                   Barlett      1
# 206                  Willie’s      1
# 207                    Willie      1
# 208             Gladys Harper      1
# 209             Pearl Guthrie      1
# 210                     Rufus      1
# 211                    Kelvin      1
# 212                     Glady      1
# 213                   Engaged      1
# 214                   Anita’s      1
# 215                      Bama      1
# 216                       Bob      1
# 217           Clifton Terrace      1
# 218                Manny Soto      1
# 219                       Heh      1
# 220           Howard Hospital      1
# 221         Sandra Wallington      1
# 222           Sherman Wheeler      1
# 223               Young Blood      1
# 224                      ODed      1
# 225                       Bet      1
# 226                  Polaroid      1
# 227                   Manny’s      1
# 228                     Elsie      1
# 229           Angelo Billings      1
# 230         Lemuel Matthews’s      1
# 231            Burberry Carol      1
# 232                     Atlas      1
# 233             Lonney McCrae      1
# 234                   Kennedy      1
# 235              Brenda Roper      1
# 236                    McCrae      1
# 237       ’s Penelope Jenkins      1
# 238               Mabel Smith      1
# 239          Gertrude Baxter—      1
# 240                    Turner      1
# 241             Penny Jenkins      1
# 242                       Ohh      1
# 243             Fort Holabird      1
# 244            Howard Theater      1
# 245                      Thou      1
# 246                    Knight      1
# 247               Dixie Peach      1
# 248                  Stanback      1
# 249                       Bat      1
# 250              Wonder Bread      1
# 251          Penelope Jenkins      1
# 252                 O. Lonney      1
# 253               Joy Lambert      1
# 254                  Kentucky      1
# 255                         N      1
# 256                    Carter      1
# 257               Carl Baggot      1
# 258           Patricia Turner      1
# 259                 Hula Hoop      1
# 260                  Soon Joy      1
# 261        Snowball Patterson      1
# 262                     Pat’s      1
# 263               Lady Baxter      1
# 264                 Kemo Sabe      1
# 265                   Severin      1
# 266            Velle” Watkins      1
# 267                Capricorns      1
# 268                    Libras      1
# 269               ’s Ballston      1
# 270                     Kinda      1
# 271                   Carlson      1
# 272    Samuel Lamont Williams      1
# 273      Agnes Marie Williams      1
# 274          John Tellingford      1
# 275                     Larry      1
# 276           Maddie Williams      1
# 277                     Aggie      1
# 278           Pookie Williams      1
# 279                   Washton      1
# 280                     Afros      1
# 281                 Clarine’s      1
# 282               Bo Cromwell      1
# 283               Sam Wallace      1
# 284    Martha Eliot Infirmary      1
# 285              Nilla Wafers      1
# 286    the Martin Luther King      1
# 287               Hazel Watts      1
# 288                 ’s Maddie      1
# 289                    D Ward      1
# 290                   Clement      1
# 291             Arnisa Isaacs      1
# 292                      Knew      1
# 293                      Bill      1
# 294                        JL      1
# 295                       Gyn      1
# 296                   Kaufman      1
# 297                  Life Bst      1
# 298                     Woolf      1
# 299                  Yale Law      1
# 300             Gail Saunders      1
# 301                      Amer      1
# 302                  Ayn Rand      1
# 303        Je m’appelle Lydia      1
# 304             Trust Capitol      1
# 305                    Empire      1
# 306                  Joseph’s      1
# 307                Cab Driver      1
# 308                       Eve      1
# 309                John Brown      1
# 310                     Night      1
# 311               Range Rover      1
# 312                     C’mon      1
# 313                    Sooner      1
# 314              Pearl Malone      1
# 315                   Pearl’s      1
# 316                      Whas      1
# 317               Sweet Jesus      1
# 318                   Sandy’d      1
# 319                   Shoulda      1
# 320                   Peebles      1
# 321            Smokey Peebles      1
# 322                     Chuck      1
# 323                  Rickey’s      1
# 324              Frankenstein      1
# 325                  Clovis’s      1
# 326                   Joyce’s      1
# 327              Jesus Christ      1
# 328                     Place      1
# 329                    Morton      1
# 330  ’s Elizabeth Ann Coleman      1
# 331          Vivian L. Slater      1
# 332                    Slater      1
# 333                    Avenue      1
# 334             Sister Slater      1
# 335            Maude Townsend      1
# 336                   Counsel      1
# 337             Melvin Ritter      1
# 338              Louis Ritter      1
# 339            Heavenly Choir      1
# 340           Jordan—\n\n\n\n      1
# 341             Forever Yours      1
# 342            Louis Ritter’s      1
# 343           Mahalia Jackson      1
# 344               Gospelteers      1
# 345                 Jesus Met      1
# 346                     Grace      1
# 347                  ’s Harry      1
# 348             Thomas Circle      1
# 349              Ralph Slater      1
# 350               Sister Rita      1
# 351                    Rita’s      1
# 352                  Rita the      1
# 353               Cunninghams      1
# 354                  Petworth      1
# 355              Lincoln Park      1
# 356                    Sparky      1
# 357                    Easter      1
# 358                   Raleigh      1
# 359               Ida Garrett      1
# 360         Beatrice Atwell’s      1
# 361                  Fraziers      1
# 362                   Jackleg      1
# 363                     Sewin      1
# 364                     Makin      1
# 365                   Frazier      1
# 366                    Arthur      1
# 367                     Uncle      1
# 368                 Uncle Joe      1
# 369                     Ebbie      1
# 370                 Uncle Ray      1
# 371                    Joseph      1
# 372                 Dickinson      1
# 373    Marie Delaveaux Wilson      1
# 374              John Smith’s      1
# 375                     White      1

# %% [markdown]
# To write this dataframe (or any dataframe!) to a CSV file, we can use `df.to_csv()`. To create a CSV file of character counts, uncomment the cell below:

# %%
#df.to_csv("Lost-in-the-City-characters.csv", encoding='utf-8', index=False)

# %% [markdown]
# # Get Places

# %% [markdown]
# |Type Label|Description|
# |:---:|:---:|
# |GPE|Countries, cities, states.|
# |LOC|Non-GPE locations, mountain ranges, bodies of water.|

# %% [markdown]
# To extract and count places, we can follow the same model as above, except we will change our `if` statement to check for "ent" labels that match "GPE" or "LOC." These are the type labels for "counties cities, states" and "locations, mountain ranges, bodies of water."

# %%
places = []
for named_entity in document.ents:
    if named_entity.label_ == "GPE" or named_entity.label_ == "LOC":
        places.append(named_entity.text)

places_tally = Counter(places)

df = pd.DataFrame(places_tally.most_common(), columns=['place', 'count'])
df
# Out:
#                         place  count
# 0                  Washington     45
# 1                   Cassandra     30
# 2                   Madeleine     25
# 3                    Kentucky     21
# 4                     Georgia     21
# 5                    Vernelle     21
# 6                    Santiago     17
# 7                      Maddie     16
# 8                   Baltimore     12
# 9                     Carmena     12
# 10                  Northeast     11
# 11                     Lorton      9
# 12                   Wilamena      9
# 13                  Northwest      7
# 14                  Anacostia      7
# 15                       D.C.      7
# 16            New York Avenue      6
# 17                  Southeast      6
# 18                     Dunbar      6
# 19                   Marvella      6
# 20                     Thelma      5
# 21                   Maryland      5
# 22                  Southwest      5
# 23                    Peoples      4
# 24                      Clara      4
# 25              North Capitol      4
# 26                   Virginia      4
# 27                 Georgetown      4
# 28                      Penny      4
# 29                     Puddin      4
# 30                      Agnes      4
# 31                      Boone      4
# 32       North Capitol Street      3
# 33              Massachusetts      3
# 34               Chesterfield      3
# 35             South Carolina      3
# 36                      Manny      3
# 37                    Jamaica      3
# 38                      South      3
# 39                      Joyce      3
# 40                     Smokey      3
# 41                     Elaine      3
# 42                    Frazier      3
# 43          New Jersey Avenue      2
# 44                    Cardozo      2
# 45                     Hudson      2
# 46                      Pearl      2
# 47                    Clifton      2
# 48              Dupont Circle      2
# 49                     Laurel      2
# 50                      Korea      2
# 51                       Argo      2
# 52                      Tonto      2
# 53             North Carolina      2
# 54            Capitol Heights      2
# 55   the District of Columbia      2
# 56                   New York      2
# 57                    Norfolk      2
# 58                Philippines      2
# 59                     Israel      2
# 60                      Jesus      2
# 61               Rhode Island      2
# 62                   Humphrey      2
# 63                     Rickey      2
# 64                      Sandy      2
# 65                     Psalms      2
# 66                  Mansfield      2
# 67                      Maude      2
# 68             the East Coast      2
# 69                Rising Star      2
# 70                    Calhoun      2
# 71                      Jenny      1
# 72                    Gonzaga      1
# 73                     Nothin      1
# 74                      Nasty      1
# 75                Dixie Peach      1
# 76                 Mt. Carmel      1
# 77                       Afro      1
# 78             Shiloh Baptist      1
# 79        East Capitol Street      1
# 80               East Capitol      1
# 81                Mississippi      1
# 82                   Kerchink      1
# 83              Silver Spring      1
# 84                  Arlington      1
# 85             the Gold Coast      1
# 86                      Bamas      1
# 87                Connecticut      1
# 88               Pennsylvania      1
# 89               Cardozo High      1
# 90                Chevy Chase      1
# 91         Dupont Circle Park      1
# 92                  Polaroids      1
# 93                   K Street      1
# 94                     Lonney      1
# 95                   Columbia      1
# 96                      China      1
# 97                     Gloria      1
# 98              Atlantic City      1
# 99              Horizon House      1
# 100                   Potomac      1
# 101                    Vienna      1
# 102                   Agnes’s      1
# 103                New Jersey      1
# 104           New York City’s      1
# 105                    Africa      1
# 106               Madeleine’s      1
# 107             Staten Island      1
# 108                 ’s Laurel      1
# 109                   Bahamas      1
# 110             Lorton Prison      1
# 111                Buckingham      1
# 112                         L      1
# 113                     Hazel      1
# 114                    Samuel      1
# 115                    Harlem      1
# 116                      Bonn      1
# 117                   Antibes      1
# 118              the Dead Sea      1
# 119                   Jericho      1
# 120                   Bethany      1
# 121                  Nazareth      1
# 122                     Lydia      1
# 123                  Cornelia      1
# 124                 New Haven      1
# 125             St. Lizabeths      1
# 126           Fort Washington      1
# 127                  Converse      1
# 128           the Range Rover      1
# 129                    Morton      1
# 130                    Gladys      1
# 131                   Mildred      1
# 132                California      1
# 133       the Anacostia River      1
# 134                  Metrobus      1
# 135                    Jordan      1
# 136                Deep River      1
# 137                    Vivian      1
# 138                  Fairmont      1
# 139                   Florida      1
# 140             Charlotesvile      1
# 141                     Mista      1
# 142              Logan Circle      1
# 143                 D.C. Born      1
# 144                 Nicodemus      1
# 145                    Kansas      1
# 146         the United States      1
# 147                    Boston      1

# %% [markdown]
# Do you notice anything off about this list...?

# %% [markdown]
# # Get Streets & Parks

# %% [markdown]
# |Type Label|Description|
# |:---:|:---:|
# |FAC|Buildings, airports, highways, bridges, etc.|

# %% [markdown]
# To extract and count streets and parks (which show up a lot in *Lost in the City*!), we can follow the same model as above, except we will change our `if` statement to check for "ent" labels that match "FAC." This is the type label for "buildings, airports, highways, bridges, etc."

# %%
streets = []
for named_entity in document.ents:
    if named_entity.label_ == "FAC":
        streets.append(named_entity.text)

streets_tally = Counter(streets)

df = pd.DataFrame(streets_tally.most_common(), columns = ['street', 'count'])
df
# Out:
#                               street  count
# 0                      Myrtle Street     10
# 1                         5th Street     10
# 2                           F Street      6
# 3                      Vernelle Wise      5
# 4                  New Jersey Avenue      4
# 5                        11th Street      4
# 6                 Connecticut Avenue      4
# 7                        10th Street      4
# 8                     Clifton Street      3
# 9                        12th Street      3
# 10                    Florida Avenue      3
# 11                    Lafayette Park      3
# 12                   New York Avenue      3
# 13                   Holy Tabernacle      3
# 14                          L Street      2
# 15               Pennsylvania Avenue      2
# 16                       15th Street      2
# 17              Massachusetts Avenue      2
# 18                              Al’s      2
# 19                        Kentucky’s      2
# 20                      Benning Road      2
# 21                    Stadium-Armory      2
# 22                  McPherson Square      2
# 23              Franklin Square Park      2
# 24                       13th Street      2
# 25             the Children’s Center      2
# 26                 Mt. Vernon Square      1
# 27                Gallinger Hospital      1
# 28                          K Street      1
# 29              1st Street Northeast      1
# 30                  Ralph’s L Street      1
# 31               Mount Vernon Square      1
# 32                     Pierce Street      1
# 33                      Third Street      1
# 34                       Cassandra’s      1
# 35                     Kenyon Street      1
# 36                          Gladys’s      1
# 37                          Rhonda’s      1
# 38                  Maple View Place      1
# 39                          C Street      1
# 40              New Hampshire Avenue      1
# 41                    Georgia Avenue      1
# 42                   Ingraham Street      1
# 43                     Manny’s Haven      1
# 44                          Regina’s      1
# 45                  Sixteenth Street      1
# 46                   the White House      1
# 47               Constitution Avenue      1
# 48                       16th Street      1
# 49                    Malcolm X Park      1
# 50                       18th Street      1
# 51                        1st Street      1
# 52                           Penny’s      1
# 53                 Penny’s Groceries      1
# 54                the Stadium-Armory      1
# 55                  National Airport      1
# 56                          Granny’s      1
# 57                   Franklin Square      1
# 58                       19th Street      1
# 59                          Marvin’s      1
# 60                      Ridge Street      1
# 61                   Sparrow’s Beach      1
# 62                     Hartnett Hall      1
# 63             21st Street Northwest      1
# 64                     the Holy Land      1
# 65                           Lydia’s      1
# 66                   1122 5th Street      1
# 67                     Ridge streets      1
# 68                  457 Ridge Street      1
# 69                        7th Street      1
# 70                          Smokey’s      1
# 71                        Santiago’s      1
# 72                  Mansfield Harper      1
# 73           Maple View in Anacostia      1
# 74                  Harmony Cemetery      1
# 75              9th Street Southeast      1
# 76                      Lincoln Park      1
# 77                M Street Northwest      1
# 78                          S Street      1
# 79          the Florida Avenue Grill      1
# 80  the Virgin Mother Baptist Church      1
# 81                   Kentucky Avenue      1
# 82                           Anita’s      1
# 83                              Rita      1
# 84                       21st Street      1
# 85               Independence Avenue      1
# 86               Rhode Island Avenue      1
# 87                        Beatrice’s      1
# 88                         Calhoun’s      1

# %% [markdown]
# # Get Works of Art

# %% [markdown]
# |Type Label|Description|
# |:---:|:---:|
# |WORK_OF_ART|Titles of books, songs, etc.|

# %% [markdown]
# To extract and count works of art, we can follow a similar-ish model to the examples above. This time, however, we're going to make our code even more economical and efficient (while still changing our `if` statement to match the "ent" label "WORK_OF_ART").

# %% [markdown]
# > 🐍 **Python Review** 🐍
#
# >We can use a [*list comprehension*](https://melaniewalsh.github.io/Intro-Cultural-Analytics/Python/More-Lists-Loops.html#List-Comprehensions) to get our list of named entities in a single line of code! Closely examine the first line of code below:

# %%
works_of_art = [named_entity.text for named_entity in document.ents if named_entity.label_ == "WORK_OF_ART"]

art_tally = Counter(works_of_art)

df = pd.DataFrame(art_tally.most_common(), columns = ['work_of_art', 'count'])
df
# Out:
#                         work_of_art  count
# 0                             Bible      9
# 1   the Declaration of Independence      2
# 2              A Deficit of Decency      1
# 3           Poor Richard’s Almanack      1
# 4   The Declaration of Independence      1
# 5               Profiles in Courage      1
# 6                    the Gilded Age      1
# 7                    the Bible Belt      1
# 8                    I Have a Dream      1
# 9          the Pledge of Allegiance      1
# 10                    Mac’s Records      1
# 11             the Dome of the Rock      1
# 12              The Two-Income Trap      1
# 13                            Shoot      1
# 14                 Hertz Rent A Car      1

# %% [markdown]
# # Your Turn!

# %% [markdown]
# Now it's your turn to take a crack at NER with a whole new text!

# %% [markdown]
# |Type Label|Description|
# |:---:|:---:|
# |PERSON|People, including fictional.|
# |NORP|Nationalities or religious or political groups.|
# |FAC|Buildings, airports, highways, bridges, etc.|
# |ORG|Companies, agencies, institutions, etc.|
# |GPE|Countries, cities, states.|
# |LOC|Non-GPE locations, mountain ranges, bodies of water.|
# |PRODUCT|Objects, vehicles, foods, etc. (Not services.)|
# |EVENT|Named hurricanes, battles, wars, sports events, etc.|
# |WORK_OF_ART|Titles of books, songs, etc.|
# |LAW|Named documents made into laws.|
# |LANGUAGE|Any named language.|
# |DATE|Absolute or relative dates or periods.|
# |TIME|Times smaller than a day.|
# |PERCENT|Percentage, including ”%“.|
# |MONEY|Monetary values, including unit.|
# |QUANTITY|Measurements, as of weight or distance.|
# |ORDINAL|“first”, “second”, etc.|
# |CARDINAL|Numerals that do not fall under another type.|

# %% [markdown]
# In this section, you're going to extract and count named entities from Barack Obama's memoir *The Audacity of Hope*. We're exploring Obama's memoir because it's chock full of named entities.

# %% [markdown]
# Read in and process the text file

# %%
file = "../texts/literature/Obama-The-Audacity-of-Hope.txt"

document = nlp(open(file, encoding='utf-8').read())

# %% [markdown]
# **1.** Choose a named entity from the possible spaCy named entities listed above. Extract, count, and make a dataframe from the most frequent named entities (of the type that you've chosen) in *The Audacity of Hope*. If you need help, study the examples above.

# %%
#Your Code Here 👇

# %% [markdown]
# **2.** What is a result from this NER extraction that conformed to your expectations, that you find obvious or predictable? Why?

# %% [markdown]
# **#**Your answer here. (Double click this cell to type your answer.)

# %% [markdown]
# **3.** What is a result from this NER extraction that defied your expectations, that you find curious or counterintuitive? Why?

# %% [markdown]
# **#**Your answer here. (Double click this cell to type your answer.)

# %% [markdown]
# **4.** What's an insight that you might be able to glean about *The Audacity of Hope* based on your NER extraction?

# %% [markdown]
# **#**Your answer here. (Double click this cell to type your answer.)
